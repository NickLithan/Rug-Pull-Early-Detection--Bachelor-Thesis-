# %% [markdown]
# Consider (additional):
# - n_transfers pre-launch vs post-launch
#
# Benchmark Features:
# ++ n_transfers, n_swaps, n_...; n_buys, n_sells
# +? buy/sell percentage; buy_sell_ratio
#
# + Initial TVL and supply, init price
# - Price and liquidity snapshots/states (?)
# + delay between pool creation and first trade
# + max_volume, time_to_max_volume
#
# + total WSOL turnover (total # traded); total sell WSOL turnover; turnover within first 1 minute / ...
# + price change within 1 minute, 5 minutes
# - price change within n blocks / ...
# - average/std relative strength index (?)
# + max price, min price, price std
# + buy price std, sell price std
# + first buy ts, first sell ts
#
# Non-Delta Benchmark
# - creation month sin vs cos (?)
# - time of day for pool deployment / trade start
# - delay between pool creation and first mint
# - architecture categories, decimals
#
# Need more info:
# - price and volume metrics in USD (?????!!!!!!)
# - n_unique_accounts (buyers vs sellers); is_pool_creator (?????!!!!!!)
#
# Can't do:
# - HHI
# - cluster coef
# - code checksums
# - commissions + bribes
